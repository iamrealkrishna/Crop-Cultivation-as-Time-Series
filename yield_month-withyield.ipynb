# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"F:\misc\UPASI Project\final\finaldata.xlsx")
df.head(10)
# Out:
#    Year  Month       Yield  Rainfall Inches  Rainfall mm  Temperature min  \
# 0  1980      1  113.079577              NaN     0.000000         5.125448
# 1  1980      2   68.103610              NaN     0.000000         7.777778
# 2  1980      3   72.051611         0.331429     1.900903         8.853047
# 3  1980      4  149.357352         0.413333     6.299200        14.074074
# 4  1980      5  314.309535         0.288824     4.023032        15.268817
# 5  1980      6  142.124603         1.698000    43.129200        16.777778
# 6  1980      7   87.412497         2.067097    52.504258        16.272401
# 7  1980      8   99.636175         1.075769    22.917355        15.931900
# 8  1980      9  164.323800         0.639500    10.828867        14.888889
# 9  1980     10  238.535173         0.351000     5.751871        14.767025
#
#    Humidity 8:30  Temperature max  Humidity 2:30
# 0            NaN        23.942652            NaN
# 1            NaN        24.750958            NaN
# ...

# %%
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#    Year  Month       Yield  Rainfall Inches  Rainfall mm  Temperature min  \
# 0  1980      1  113.079577         0.000000     0.000000         5.125448
# 1  1980      2   68.103610         0.000000     0.000000         7.777778
# 2  1980      3   72.051611         0.331429     1.900903         8.853047
# 3  1980      4  149.357352         0.413333     6.299200        14.074074
# 4  1980      5  314.309535         0.288824     4.023032        15.268817
#
#    Humidity 8:30  Temperature max  Humidity 2:30
# 0            0.0        23.942652            0.0
# 1            0.0        24.750958            0.0
# 2            0.0        25.483871            0.0
# 3            0.0        24.333333            0.0
# 4            0.0        25.017921            0.0

# %%
df['Yield']=df['Yield'].astype('float')
df
# Out:
#      Year  Month       Yield  Rainfall Inches  Rainfall mm  Temperature min  \
# 0    1980      1  113.079577         0.000000     0.000000         5.125448
# 1    1980      2   68.103610         0.000000     0.000000         7.777778
# 2    1980      3   72.051611         0.331429     1.900903         8.853047
# 3    1980      4  149.357352         0.413333     6.299200        14.074074
# 4    1980      5  314.309535         0.288824     4.023032        15.268817
# ..    ...    ...         ...              ...          ...              ...
# 487  2020      8  162.000000         1.520667    37.378968        14.258065
# 488  2020      9  200.000000         1.268214    30.065133        14.433333
# 489  2020     10  195.000000         0.339643     7.792065        13.000000
# 490  2020     11  236.000000         0.135667     3.445933        11.533333
# 491  2020     12  240.000000         0.068519     1.515806        10.129032
#
#      Humidity 8:30  Temperature max  Humidity 2:30
# ...

# %%
df
# Out:
#      Year  Month       Yield  Rainfall Inches  Rainfall mm  Temperature min  \
# 0    1980      1  113.079577         0.000000     0.000000         5.125448
# 1    1980      2   68.103610         0.000000     0.000000         7.777778
# 2    1980      3   72.051611         0.331429     1.900903         8.853047
# 3    1980      4  149.357352         0.413333     6.299200        14.074074
# 4    1980      5  314.309535         0.288824     4.023032        15.268817
# ..    ...    ...         ...              ...          ...              ...
# 487  2020      8  162.000000         1.520667    37.378968        14.258065
# 488  2020      9  200.000000         1.268214    30.065133        14.433333
# 489  2020     10  195.000000         0.339643     7.792065        13.000000
# 490  2020     11  236.000000         0.135667     3.445933        11.533333
# 491  2020     12  240.000000         0.068519     1.515806        10.129032
#
#      Humidity 8:30  Temperature max  Humidity 2:30
# ...

# %%
df['Rainfall Inches']=df['Rainfall Inches'].astype('float')
df
# Out:
#      Year  Month       Yield  Rainfall Inches  Rainfall mm  Temperature min  \
# 0    1980      1  113.079577         0.000000     0.000000         5.125448
# 1    1980      2   68.103610         0.000000     0.000000         7.777778
# 2    1980      3   72.051611         0.331429     1.900903         8.853047
# 3    1980      4  149.357352         0.413333     6.299200        14.074074
# 4    1980      5  314.309535         0.288824     4.023032        15.268817
# ..    ...    ...         ...              ...          ...              ...
# 487  2020      8  162.000000         1.520667    37.378968        14.258065
# 488  2020      9  200.000000         1.268214    30.065133        14.433333
# 489  2020     10  195.000000         0.339643     7.792065        13.000000
# 490  2020     11  236.000000         0.135667     3.445933        11.533333
# 491  2020     12  240.000000         0.068519     1.515806        10.129032
#
#      Humidity 8:30  Temperature max  Humidity 2:30
# ...

# %%
df['Rainfall mm']=df['Rainfall mm'].astype('float')
df['Temperature min']=df['Temperature min'].astype('float')
df['Temperature max']=df['Temperature max'].astype('float')
df['Humidity 8:30']=df['Humidity 8:30'].astype('float')
df['Humidity 2:30']=df['Humidity 2:30'].astype('float')
df
# Out:
#      Year  Month       Yield  Rainfall Inches  Rainfall mm  Temperature min  \
# 0    1980      1  113.079577         0.000000     0.000000         5.125448
# 1    1980      2   68.103610         0.000000     0.000000         7.777778
# 2    1980      3   72.051611         0.331429     1.900903         8.853047
# 3    1980      4  149.357352         0.413333     6.299200        14.074074
# 4    1980      5  314.309535         0.288824     4.023032        15.268817
# ..    ...    ...         ...              ...          ...              ...
# 487  2020      8  162.000000         1.520667    37.378968        14.258065
# 488  2020      9  200.000000         1.268214    30.065133        14.433333
# 489  2020     10  195.000000         0.339643     7.792065        13.000000
# 490  2020     11  236.000000         0.135667     3.445933        11.533333
# 491  2020     12  240.000000         0.068519     1.515806        10.129032
#
#      Humidity 8:30  Temperature max  Humidity 2:30
# ...

# %%
date = [str(y)+'-'+str(m) for y, m in zip(df.Year, df.Month)]

# %%
df.index = pd.to_datetime(date)

# %%
df['date'] = df.index
df['dayofyear']=df['date'].dt.dayofyear
df.drop('date',axis=1,inplace=True)
df.head()
# Out:
#             Year  Month       Yield  Rainfall Inches  Rainfall mm  \
# 1980-01-01  1980      1  113.079577         0.000000     0.000000
# 1980-02-01  1980      2   68.103610         0.000000     0.000000
# 1980-03-01  1980      3   72.051611         0.331429     1.900903
# 1980-04-01  1980      4  149.357352         0.413333     6.299200
# 1980-05-01  1980      5  314.309535         0.288824     4.023032
#
#             Temperature min  Humidity 8:30  Temperature max  Humidity 2:30  \
# 1980-01-01         5.125448            0.0        23.942652            0.0
# 1980-02-01         7.777778            0.0        24.750958            0.0
# 1980-03-01         8.853047            0.0        25.483871            0.0
# 1980-04-01        14.074074            0.0        24.333333            0.0
# 1980-05-01        15.268817            0.0        25.017921            0.0
#
#             dayofyear
# 1980-01-01          1
# 1980-02-01         32
# 1980-03-01         61
# 1980-04-01         92
# ...

# %%
df['Temp'] = df[['Temperature min', 'Temperature max']].mean(axis=1)
df['Humidity'] = df[['Humidity 8:30', 'Humidity 2:30']].mean(axis=1)
df
# Out:
#             Year  Month       Yield  Rainfall Inches  Rainfall mm  \
# 1980-01-01  1980      1  113.079577         0.000000     0.000000
# 1980-02-01  1980      2   68.103610         0.000000     0.000000
# 1980-03-01  1980      3   72.051611         0.331429     1.900903
# 1980-04-01  1980      4  149.357352         0.413333     6.299200
# 1980-05-01  1980      5  314.309535         0.288824     4.023032
# ...          ...    ...         ...              ...          ...
# 2020-08-01  2020      8  162.000000         1.520667    37.378968
# 2020-09-01  2020      9  200.000000         1.268214    30.065133
# 2020-10-01  2020     10  195.000000         0.339643     7.792065
# 2020-11-01  2020     11  236.000000         0.135667     3.445933
# 2020-12-01  2020     12  240.000000         0.068519     1.515806
#
#             Temperature min  Humidity 8:30  Temperature max  Humidity 2:30  \
# 1980-01-01         5.125448       0.000000        23.942652       0.000000
# ...

# %%
df
# Out:
#             Year  Month       Yield  Rainfall Inches  Rainfall mm  \
# 1980-01-01  1980      1  113.079577         0.000000     0.000000
# 1980-02-01  1980      2   68.103610         0.000000     0.000000
# 1980-03-01  1980      3   72.051611         0.331429     1.900903
# 1980-04-01  1980      4  149.357352         0.413333     6.299200
# 1980-05-01  1980      5  314.309535         0.288824     4.023032
# ...          ...    ...         ...              ...          ...
# 2020-08-01  2020      8  162.000000         1.520667    37.378968
# 2020-09-01  2020      9  200.000000         1.268214    30.065133
# 2020-10-01  2020     10  195.000000         0.339643     7.792065
# 2020-11-01  2020     11  236.000000         0.135667     3.445933
# 2020-12-01  2020     12  240.000000         0.068519     1.515806
#
#             Temperature min  Humidity 8:30  Temperature max  Humidity 2:30  \
# 1980-01-01         5.125448       0.000000        23.942652       0.000000
# ...

# %%
df.plot(x='Year',y='Yield',style='.', figsize=(15,5))

# %%
train = df.loc[df['Year'] <= 2019]
test = df.loc[df['Year'] == 2020]
df.head()
# Out:
#             Year  Month       Yield  Rainfall Inches  Rainfall mm  \
# 1980-01-01  1980      1  113.079577         0.000000     0.000000
# 1980-02-01  1980      2   68.103610         0.000000     0.000000
# 1980-03-01  1980      3   72.051611         0.331429     1.900903
# 1980-04-01  1980      4  149.357352         0.413333     6.299200
# 1980-05-01  1980      5  314.309535         0.288824     4.023032
#
#             Temperature min  Humidity 8:30  Temperature max  Humidity 2:30  \
# 1980-01-01         5.125448            0.0        23.942652            0.0
# 1980-02-01         7.777778            0.0        24.750958            0.0
# 1980-03-01         8.853047            0.0        25.483871            0.0
# 1980-04-01        14.074074            0.0        24.333333            0.0
# 1980-05-01        15.268817            0.0        25.017921            0.0
#
#             dayofyear       Temp  Humidity
# 1980-01-01          1  14.534050       0.0
# ...

# %%
X_train=train.drop(['Rainfall mm','Temperature min','Temperature max','Humidity 8:30','Humidity 2:30'],axis=1)
Y_train=train['Yield']
X_train
# Out:
#             Year  Month       Yield  Rainfall Inches  dayofyear       Temp  \
# 1980-01-01  1980      1  113.079577         0.000000          1  14.534050
# 1980-02-01  1980      2   68.103610         0.000000         32  16.264368
# 1980-03-01  1980      3   72.051611         0.331429         61  17.168459
# 1980-04-01  1980      4  149.357352         0.413333         92  19.203704
# 1980-05-01  1980      5  314.309535         0.288824        122  20.143369
# ...          ...    ...         ...              ...        ...        ...
# 2019-08-01  2019      8  170.000000         1.780000        213  17.241935
# 2019-09-01  2019      9  160.000000         0.898519        244  19.416667
# 2019-10-01  2019     10  268.000000         0.604167        274  18.645161
# 2019-11-01  2019     11  243.000000         0.042692        305  17.783333
# 2019-12-01  2019     12  189.000000         0.040690        335  17.096774
#
#              Humidity
# 1980-01-01   0.000000
# ...

# %%
X_test=test.drop(['Rainfall mm','Temperature min','Temperature max','Humidity 8:30','Humidity 2:30'],axis=1)
Y_test=test['Yield']
X_test
# Out:
#             Year  Month  Yield  Rainfall Inches  dayofyear       Temp  \
# 2020-01-01  2020      1  224.0         0.000000          1  15.435484
# 2020-02-01  2020      2  171.0         0.000000         32  15.724138
# 2020-03-01  2020      3  128.0         0.075385         61  17.532258
# 2020-04-01  2020      4  189.0         0.170000         92  18.333333
# 2020-05-01  2020      5  314.0         0.152593        122  19.806452
# 2020-06-01  2020      6  226.0         0.587667        153  18.966667
# 2020-07-01  2020      7  189.0         0.825517        183  18.419355
# 2020-08-01  2020      8  162.0         1.520667        214  17.403226
# 2020-09-01  2020      9  200.0         1.268214        245  17.466667
# 2020-10-01  2020     10  195.0         0.339643        275  17.177419
# 2020-11-01  2020     11  236.0         0.135667        306  17.833333
# 2020-12-01  2020     12  240.0         0.068519        336  16.774194
#
#              Humidity
# 2020-01-01  76.774194
# ...

# %%
from sklearn.svm import SVR
regressor=SVR(gamma='scale',kernel='poly',degree=11)
regressor.fit(X_train,Y_train)
Y_pred = regressor.predict(X_test)

# %%
regressor.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 11,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'poly',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
df1 = pd.DataFrame({'Actual Yield': Y_test, 'Predicted Yield': Y_pred})  
df1[df1['Predicted Yield']!=0].head(10)
# Out:
#             Actual Yield  Predicted Yield
# 2020-01-01         224.0       217.133723
# 2020-02-01         171.0       175.980269
# 2020-03-01         128.0       143.249043
# 2020-04-01         189.0       192.408056
# 2020-05-01         314.0       303.550794
# 2020-06-01         226.0       226.350917
# 2020-07-01         189.0       195.704231
# 2020-08-01         162.0       173.697388
# 2020-09-01         200.0       207.341321
# 2020-10-01         195.0       203.539403

# %%
Y_test1=test['Yield']

# %%
plt.figure(figsize=(20,10))
plt.scatter(X_test['Month'],Y_test1,color='red')
plt.plot(X_test['Month'],Y_test,color='green')
plt.plot(X_test['Month'],Y_pred,color='blue')

# %%
df1.plot(figsize=(15,4))
df1.plot(subplots=True, figsize=(15,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FF84E5CA90>,
# ...
#       dtype=object)

# %%
from sklearn.metrics import r2_score 
r2 = r2_score(Y_test, Y_pred) 
r2
# Out:
# 0.9666911566653742

# %%
from sklearn.metrics import mean_absolute_error as mae

mae(Y_test, Y_pred,multioutput='uniform_average')
# Out:
# 7.3443527505385475

# %%
import math
MSE = np.square(np.subtract(Y_test, Y_pred)).mean() 
 
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 8.23369138892718

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test, Y_pred)
# Out:
# 67.79367388809361

# %%
from sklearn.metrics import mean_absolute_error
mape = mean_absolute_error(Y_test, Y_pred)*100
print(mape)
# Out:
# 734.4352750538548

# %%
X_train.fillna(0, inplace=True)
Y_train.fillna(0, inplace=True)
X_test.fillna(0, inplace=True)
Y_test.fillna(0, inplace=True)
X_train=X_train.astype('int')
Y_train=Y_train.astype('int')
X_test=X_test.astype('int')
Y_test=Y_test.astype('int')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
X_train
# Out:
#             Year  Month  Yield  Rainfall Inches  dayofyear  Temp  Humidity
# 1980-01-01  1980      1    113                0          1    14         0
# 1980-02-01  1980      2     68                0         32    16         0
# 1980-03-01  1980      3     72                0         61    17         0
# 1980-04-01  1980      4    149                0         92    19         0
# 1980-05-01  1980      5    314                0        122    20         0
# ...          ...    ...    ...              ...        ...   ...       ...
# 2019-08-01  2019      8    170                1        213    17        95
# 2019-09-01  2019      9    160                0        244    19        92
# 2019-10-01  2019     10    268                0        274    18        88
# 2019-11-01  2019     11    243                0        305    17        82
# 2019-12-01  2019     12    189                0        335    17        79
#
# [480 rows x 7 columns]

# %%
X_test
# Out:
#             Year  Month  Yield  Rainfall Inches  dayofyear  Temp  Humidity
# 2020-01-01  2020      1    224                0          1    15        76
# 2020-02-01  2020      2    171                0         32    15        83
# 2020-03-01  2020      3    128                0         61    17        84
# 2020-04-01  2020      4    189                0         92    18        84
# 2020-05-01  2020      5    314                0        122    19        83
# 2020-06-01  2020      6    226                0        153    18        89
# 2020-07-01  2020      7    189                0        183    18        91
# 2020-08-01  2020      8    162                1        214    17        91
# 2020-09-01  2020      9    200                1        245    17        92
# 2020-10-01  2020     10    195                0        275    17        85
# 2020-11-01  2020     11    236                0        306    17        79
# ...

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(18,18,18),max_iter=2000)
mlp.fit(X_train,Y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(18, 18, 18), max_iter=2000)

# %%
Y_pred1 = mlp.predict(X_test)

# %%
mlp.get_params()
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': (18, 18, 18),
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 2000,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': None,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
df2 = pd.DataFrame({'Actual Yield': Y_test, 'Predicted Yield': Y_pred1})  
df2[df2['Predicted Yield']!=0].head(10)
# Out:
#             Actual Yield  Predicted Yield
# 2020-01-01           224              201
# 2020-02-01           171              166
# 2020-03-01           128              128
# 2020-04-01           189              187
# 2020-05-01           314              313
# 2020-06-01           226              241
# 2020-07-01           189              194
# 2020-08-01           162              170
# 2020-09-01           200              203
# 2020-10-01           195              188

# %%
df2.plot(figsize=(15,4))
df2.plot(subplots=True, figsize=(15,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FF89809130>,
# ...
#       dtype=object)

# %%
from sklearn.metrics import r2_score 
r2 = r2_score(Y_test, Y_pred1) 
r2
# Out:
# 0.9493933479821485

# %%
from sklearn import svm
from sklearn.svm import SVC
model = svm.SVC(gamma='scale',kernel='poly',degree=16)
model.fit(X_train, Y_train)
# Out:
# SVC(degree=16, kernel='poly')

# %%
Y_pred2 = model.predict(X_test)

# %%
df1 = pd.DataFrame({'Actual Yield': Y_test, 'Predicted Yield': Y_pred2})  
df1[df1['Predicted Yield']!=0].head(10)
# Out:
#             Actual Yield  Predicted Yield
# 2020-01-01           224              210
# 2020-02-01           171              184
# 2020-03-01           128              135
# 2020-04-01           189              184
# 2020-05-01           314              329
# 2020-06-01           226              200
# 2020-07-01           189              184
# 2020-08-01           162              184
# 2020-09-01           200              181
# 2020-10-01           195              204

# %%
r2 = r2_score(Y_test, Y_pred2) 
r2
# Out:
# 0.8992370787896985

# %%
from sklearn.neighbors import KNeighborsClassifier
neig = KNeighborsClassifier(n_neighbors=24)
neig.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=24)

# %%
Y_pred3 = neig.predict(X_test)

# %%
df1 = pd.DataFrame({'Actual Yield': Y_test, 'Predicted Yield': Y_pred3})  
df1[df1['Predicted Yield']!=0].head(10)
# Out:
#             Actual Yield  Predicted Yield
# 2020-01-01           224              201
# 2020-02-01           171              146
# 2020-03-01           128              133
# 2020-04-01           189              185
# 2020-05-01           314              313
# 2020-06-01           226              202
# 2020-07-01           189              184
# 2020-08-01           162              170
# 2020-09-01           200              194
# 2020-10-01           195              198

# %%
r2 = r2_score(Y_test, Y_pred3) 
r2
# Out:
# 0.8570648687748222
